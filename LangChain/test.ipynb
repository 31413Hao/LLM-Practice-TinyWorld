# %%
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage

# 创建LLM实例
llm = ChatOpenAI(
    temperature=0.7,
    model="glm-4.5",
    openai_api_key="f532b4bd71324c1ca2fd7e22d4eb41da.4Sfpr8wE6qEVV5BY",
    openai_api_base="https://open.bigmodel.cn/api/paas/v4/"
)

# 创建消息
messages = [
    SystemMessage(content="你是一个有用的AI助手"),
    HumanMessage(content="请介绍一下人工智能的发展历程")
]

# 调用模型
response = llm(messages)
print(response.content)
# Out:
# # 人工智能的发展历程
#
# 人工智能(AI)的发展是一个跨越数十年的过程，经历了多次起伏与突破。以下是其主要发展阶段：
#
# ## 1. 早期思想萌芽与理论基础（1940s-1950s）
# - **1943年**：麦卡洛克和皮茨提出第一个人工神经元模型，为神经网络奠定基础
# - **1950年**：艾伦·图灵提出著名的"图灵测试"，在论文《计算机器与智能》中探讨机器能否思考
# - **1956年前**：香农研究电脑下棋，明斯基建造首个神经网络机器SNARC
#
# ## 2. 人工智能的诞生与初期发展（1950s-1960s）
# - **1956年**：达特茅斯会议正式确立"人工智能"这一学科名称，由约翰·麦卡锡提出
# - **1950s末-1960s初**：AI"黄金时代"
#   - 纽厄尔和西蒙开发"逻辑理论家"和"通用问题解决器"(GPS)
#   - 亚瑟·塞缪尔开发首个能学习的跳棋程序
#   - 1965年，约瑟夫·魏森鲍姆创建ELIZA对话系统
#
# ## 3. 第一次AI低谷（1970s-1980s初）
# - **1973年**：英国莱特希尔报告批评AI研究进展缓慢，导致资金削减
# - **1974-1980年**："第一次AI冬天"
#   - 计算能力限制
#   - 组合爆炸问题
#   - 知识获取困难
#   - 基础理论不足
#
# ## 4. 专家系统的兴起（1980s）
# - **1980年代初**：专家系统带来AI复兴
#   - MYCIN：医疗诊断系统
#   - DENDRAL：化学分析系统
#   - XCON/R1：计算机配置系统
# - **1980年代中期**：日本"第五代计算机"项目、美国MCC联盟、英国Alvey计划等政府项目大量投资AI
#
# ## 5. 第二次AI低谷（1990s初）
# - **1980年代末-1990年代初**：专家系统局限性显现
#   - 知识获取瓶颈
#   - 缺乏学习能力
#   - 应用领域有限
#   - 维护成本高
# - **1991-1993年**：冷战结束，政府资金减少，"第二次AI冬天"
#
# ## 6. 统计学习与实用主义（1990s-2000s）
# - **1990年代中期**：AI研究转向基于统计和概率的方法
# - **重要进展**：
#   - **1997年**：IBM深蓝战胜国际象棋世界冠军卡斯帕罗夫
#   - 支持向量机(SVM)、贝叶斯网络等统计学习方法广泛应用
#   - 数据挖掘技术快速发展
# - **2004年**：DARPA举办首次无人驾驶汽车挑战赛
#
# ## 7. 深度学习革命（2010s至今）
# - **2006年**：杰弗里·辛顿提出深度学习有效训练方法
# - **2011年**：IBM Watson在《Jeopardy!》智力问答节目中战胜人类冠军
# - **2012年**：AlexNet在ImageNet图像识别挑战赛中取得突破性胜利
# - **2014年**：Facebook开发DeepFace面部识别系统；谷歌收购DeepMind
# - **2016年**：AlphaGo战胜世界围棋冠军李世石
# - **2017年**：Transformer架构提出，推动自然语言处理发展
# - **2018-2019年**：BERT、GPT等大型语言模型展示强大能力
# - **2020年**：GPT-3展示前所未有的语言生成能力；AlphaFold解决蛋白质结构预测问题
# - **2022-2023年**：ChatGPT、GPT-4等大型语言模型和生成式AI快速发展
#
# ## 8. 当代AI发展与未来展望
# - **当前趋势**：
#   - 大规模预训练模型
#   - 多模态AI
#   - 自监督学习
#   - AI伦理与安全研究
#
# - **挑战与问题**：
#   - 可解释性
#   - 数据偏见
#   - 隐私保护
#   - 安全与对齐
#   - 能源消耗
#
# - **未来展望**：
#   - 通用人工智能(AGI)
#   - 人机协作
#   - AI在科学发现中的应用
#   - 边缘AI与低资源AI
#
# 人工智能的发展历程展示了从理论探索到实践应用，从规则驱动到数据驱动的转变。随着技术不断进步，AI正在深刻改变我们的生活和工作方式，同时也带来了一系列需要全社会共同面对的挑战。
